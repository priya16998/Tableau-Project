# %% [markdown]
# <a href="https://colab.research.google.com/github/priya16998/Tableau-Project/blob/main/Python_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
dataframe = pd.read_csv("/ProjectOrder.csv")
print(dataframe)
# Out:
#       Order ID  Order Date  Order Quantity      Sales       Ship Mode  \
# 0          3.0  13-10-2010             6.0   261.5400     Regular Air
# 1          6.0  20-02-2012             2.0     6.9300     Regular Air
# 2         32.0  15-07-2011            26.0  2808.0800     Regular Air
# 3         32.0  15-07-2011            24.0  1761.4000  Delivery Truck
# 4         32.0  15-07-2011            23.0   160.2335     Regular Air
# ...        ...         ...             ...        ...             ...
# 1027       NaN         NaN             NaN        NaN             NaN
# 1028       NaN         NaN             NaN        NaN             NaN
# 1029       NaN         NaN             NaN        NaN             NaN
# 1030       NaN         NaN             NaN        NaN             NaN
# 1031       NaN         NaN             NaN        NaN             NaN
#
#        Profit  Unit Price       Customer Name Customer Segment  \
# ...

# %%
print(dataframe['Sales'].head())
print(dataframe['Sales'].dtype)
# Out:
# 0     261.5400
# 1       6.9300
# 2    2808.0800
# 3    1761.4000
# 4     160.2335
# Name: Sales, dtype: float64
# float64

# %% [markdown]
# def handleRate(value):
#     try:
#         value = str(value).strip()
#         if not value or value.lower() in ['nan', 'none', '', 'null']:
#             return np.nan
#
#         value = value.split('.')[0]
#         return float(value)
#     except Exception:
#         return np.nan
#         dataframe['Sales'] = dataframe['Sales'].apply(handleRate)
#         print(dataframe['Sales'].head())

# %%
print(dataframe.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1032 entries, 0 to 1031
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          1007 non-null   float64
#  1   Order Date        1007 non-null   object
#  2   Order Quantity    1007 non-null   float64
#  3   Sales             1007 non-null   float64
#  4   Ship Mode         1007 non-null   object
#  5   Profit            1007 non-null   float64
#  6   Unit Price        1007 non-null   float64
#  7   Customer Name     1007 non-null   object
#  8   Customer Segment  1007 non-null   object
#  9   Product Category  1007 non-null   object
# dtypes: float64(5), object(5)
# memory usage: 80.8+ KB
# None

# %%
sns.countplot(x=dataframe['Product Category'])
sns.countplot(x=dataframe['Product Category'])
plt.xlabel("PRODUCTS")
plt.figure(figsize=(2, 4))
plt.show()

# %%
sns.countplot(x=dataframe['Sales'])
plt.xlabel("SALES")
sns.countplot(y=dataframe['Ship Mode'])
plt.ylabel("SHIP MODE")
plt.show()

# %%
dataframe.head()
# Out:
#    Order ID  Order Date  Order Quantity      Sales       Ship Mode   Profit  \
# 0       3.0  13-10-2010             6.0   261.5400     Regular Air  -213.25
# 1       6.0  20-02-2012             2.0     6.9300     Regular Air    -4.64
# 2      32.0  15-07-2011            26.0  2808.0800     Regular Air  1054.82
# 3      32.0  15-07-2011            24.0  1761.4000  Delivery Truck -1748.56
# 4      32.0  15-07-2011            23.0   160.2335     Regular Air   -85.13
#
#    Unit Price       Customer Name Customer Segment Product Category
# 0       38.94  Muhammed MacIntyre   Small Business  Office Supplies
# 1        2.08         Ruben Dartt        Corporate  Office Supplies
# 2      107.53       Liz Pelletier        Corporate        Furniture
# 3       70.89       Liz Pelletier        Corporate        Furniture
# 4        7.99       Liz Pelletier        Corporate       Technology

# %%
dataframe.head(10)
# Out:
#    Order ID  Order Date  Order Quantity      Sales       Ship Mode   Profit  \
# 0       3.0  13-10-2010             6.0   261.5400     Regular Air  -213.25
# 1       6.0  20-02-2012             2.0     6.9300     Regular Air    -4.64
# 2      32.0  15-07-2011            26.0  2808.0800     Regular Air  1054.82
# 3      32.0  15-07-2011            24.0  1761.4000  Delivery Truck -1748.56
# 4      32.0  15-07-2011            23.0   160.2335     Regular Air   -85.13
# 5      32.0  15-07-2011            15.0   140.5600     Regular Air  -128.38
# 6      35.0  22-10-2011            30.0   288.5600     Regular Air    60.72
# 7      35.0  22-10-2011            14.0  1892.8480     Regular Air    48.99
# 8      36.0  02-11-2011            46.0  2484.7455     Regular Air   657.48
# 9      65.0  17-03-2011            32.0  3812.7300     Regular Air  1470.30
#
#    Unit Price       Customer Name Customer Segment Product Category
# ...

# %%
dataframe.head(50)
# Out:
#     Order ID  Order Date  Order Quantity      Sales       Ship Mode   Profit  \
# 0        3.0  13-10-2010             6.0   261.5400     Regular Air  -213.25
# 1        6.0  20-02-2012             2.0     6.9300     Regular Air    -4.64
# 2       32.0  15-07-2011            26.0  2808.0800     Regular Air  1054.82
# 3       32.0  15-07-2011            24.0  1761.4000  Delivery Truck -1748.56
# 4       32.0  15-07-2011            23.0   160.2335     Regular Air   -85.13
# 5       32.0  15-07-2011            15.0   140.5600     Regular Air  -128.38
# 6       35.0  22-10-2011            30.0   288.5600     Regular Air    60.72
# 7       35.0  22-10-2011            14.0  1892.8480     Regular Air    48.99
# 8       36.0  02-11-2011            46.0  2484.7455     Regular Air   657.48
# 9       65.0  17-03-2011            32.0  3812.7300     Regular Air  1470.30
# 10      32.0  15-07-2008            26.0  2795.7800     Regular Air     0.00
# ...

# %%
grouped_data = dataframe.groupby('Customer Segment')['Sales'].sum()
result = pd.DataFrame({'Sales':grouped_data})
plt.plot(result, c="orange", marker="o")
plt.xlabel("Customer Segment",c="maroon",size=12)
plt.ylabel("Sales", c="maroon", size=12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Conclusion:** Through the line graph we can clearly state that we get our highest Sales from the Corporate Segment. Whereas, consumer and small business segment has the lowest sales. Therefore we have to comeup with ideas to attract consumers and small business.

# %%
dataframe.head()
# Out:
#    Order ID  Order Date  Order Quantity      Sales       Ship Mode   Profit  \
# 0       3.0  13-10-2010             6.0   261.5400     Regular Air  -213.25
# 1       6.0  20-02-2012             2.0     6.9300     Regular Air    -4.64
# 2      32.0  15-07-2011            26.0  2808.0800     Regular Air  1054.82
# 3      32.0  15-07-2011            24.0  1761.4000  Delivery Truck -1748.56
# 4      32.0  15-07-2011            23.0   160.2335     Regular Air   -85.13
#
#    Unit Price       Customer Name Customer Segment Product Category
# 0       38.94  Muhammed MacIntyre   Small Business  Office Supplies
# 1        2.08         Ruben Dartt        Corporate  Office Supplies
# 2      107.53       Liz Pelletier        Corporate        Furniture
# 3       70.89       Liz Pelletier        Corporate        Furniture
# 4        7.99       Liz Pelletier        Corporate       Technology

# %%
# @title Customer Segment

from matplotlib import pyplot as plt
import seaborn as sns
dataframe.groupby('Customer Segment').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
plt.hist(dataframe['Order Quantity'],bins=25)
plt.title("Quantity sold in per order")
plt.show()

# %% [markdown]
# **Conclusion:** The majority of quantity sold by the company to it's clients anr nearly around 7-8 or, 3-4 or, 29-30 or, 40-41.

# %%
dataframe.head()
# Out:
#    Order ID  Order Date  Order Quantity      Sales       Ship Mode   Profit  \
# 0       3.0  13-10-2010             6.0   261.5400     Regular Air  -213.25
# 1       6.0  20-02-2012             2.0     6.9300     Regular Air    -4.64
# 2      32.0  15-07-2011            26.0  2808.0800     Regular Air  1054.82
# 3      32.0  15-07-2011            24.0  1761.4000  Delivery Truck -1748.56
# 4      32.0  15-07-2011            23.0   160.2335     Regular Air   -85.13
#
#    Unit Price       Customer Name Customer Segment Product Category
# 0       38.94  Muhammed MacIntyre   Small Business  Office Supplies
# 1        2.08         Ruben Dartt        Corporate  Office Supplies
# 2      107.53       Liz Pelletier        Corporate        Furniture
# 3       70.89       Liz Pelletier        Corporate        Furniture
# 4        7.99       Liz Pelletier        Corporate       Technology

# %%
# @title Profit vs Unit Price

from matplotlib import pyplot as plt
dataframe.plot(kind='scatter', x='Profit', y='Unit Price', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Sales vs Profit

from matplotlib import pyplot as plt
dataframe.plot(kind='scatter', x='Sales', y='Profit', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Profit

from matplotlib import pyplot as plt
dataframe['Profit'].plot(kind='hist', bins=20, title='Profit')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Sales

from matplotlib import pyplot as plt
dataframe['Sales'].plot(kind='hist', bins=20, title='Sales')
plt.gca().spines[['top', 'right',]].set_visible(False)
